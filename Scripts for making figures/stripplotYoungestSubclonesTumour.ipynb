# %%
"""
    File : stripplotYoungestSubclonesTumour.ipynb
    Plot : stripplot of the distances from regions harbouring recent subclones to tumour margin in RCC tumours
    Inputs : 
        SourceData_Fig4e.xlsx
        
    Note that the positions of data points may slightly differ in different
    iterations of Seaborn stripplot function call
"""

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path_to_all_source_data = "../Source data for figures"

# %%
def plot_data(
    single_region_events,
    single_region_events_mean_d2margin
):
    def config_font_size(figsize):
        params = {'legend.fontsize': 6,
                  'figure.figsize': figsize,
                 'axes.labelsize': 8,
                 'axes.titlesize': 8,
                 'xtick.labelsize':6,
                 'ytick.labelsize':6,
                 'pdf.fonttype':42}
        plt.rcParams.update(params)

    fig = plt.figure(dpi=300)
    ax = fig.add_axes([0.2,0.2,0.75,0.75])

    config_font_size(figsize = (2.75,3))
    
    order_tumours = single_region_events_mean_d2margin.TumourK.values.tolist()

    sns.stripplot(
        data=single_region_events,
        y='TumourK',
        x='D2Margin',
        orient='h',
        ax=ax,
        size=2,
        order=order_tumours,
        zorder=2
    )

    ax.scatter(
        single_region_events_mean_d2margin.D2MarginMean,
        single_region_events_mean_d2margin.TumourK,  
        s = 0.5, marker = '_', c = 'k', zorder = 3
    )

    ax.set_xlim([0,35])
    ax.axvline(x = 10, c = 'grey', lw = 0.5, zorder = 1, ls = '--')

    ax.tick_params(axis='y', which='major', labelsize=3.5)

    ax.set_xlabel('Distance to margin (mm)')
    ax.set_ylabel('Tumour ID')

    plt.show()

# %% [markdown]
# # Figure 4e

# %%
path_to_excelfile = os.path.join(
    path_to_all_source_data,
    "Source_Data_Figure_4",
    "SourceData_Fig4e.xlsx"
)

# %%
excelfile = pd.ExcelFile(path_to_excelfile)
excelfile.sheet_names
# Out:
# ['SourceDataFig4eInput1', 'SourceDataFig4eInput2']

# %%
single_region_events = pd.read_excel(
    excelfile, 
    sheet_name='SourceDataFig4eInput1'
)
single_region_events_mean_d2margin = pd.read_excel(
    excelfile, 
    sheet_name='SourceDataFig4eInput2'
)

# %%
plot_data(
    single_region_events,
    single_region_events_mean_d2margin
)

# %% [markdown]
# # Extended Data Figure 7b

# %%
path_to_excelfile = os.path.join(
    path_to_all_source_data,
    "Source_Data_Extended_Data_Figure_7",
    "SourceData_ExtendedData_Fig7b.xlsx"
)

# %%
excelfile = pd.ExcelFile(path_to_excelfile)
excelfile.sheet_names
# Out:
# ['SourceDataEDFig7bInput1', 'SourceDataEDFig7bInput2']

# %%
single_region_events = pd.read_excel(
    excelfile, 
    sheet_name='SourceDataEDFig7bInput1'
)
single_region_events_mean_d2margin = pd.read_excel(
    excelfile, 
    sheet_name='SourceDataEDFig7bInput2'
)

# %%
plot_data(
    single_region_events,
    single_region_events_mean_d2margin
)
